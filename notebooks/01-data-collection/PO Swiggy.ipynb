# %%
import pandas as pd

# %%
df = pd.read_excel("./../data/raw/swiggy/PO/DOC-20251006-WA0039.xlsx")

# %%
df.iloc[: df["Item Name"].isna().idxmax()]
# Out:
#                   Item Name   Order in kg October 6  Unnamed: 2  Unnamed: 3
# 0                      Beet                    65.0        50.0      3250.0
# 1             bottle gourd                     23.0       350.0      8050.0
# 2                  cabbage                    106.0        20.0      2120.0
# 3           Cucumber white                     29.0        16.0       464.0
# 4             French beans                     24.0        70.0      1680.0
# 5            garlic peeled                      4.5       100.0       450.0
# 6           Green capsicum                      8.0       550.0      4400.0
# 7           Green Cucumber                      5.0       350.0      1750.0
# 8                    lemon                     20.0        65.0      1300.0
# 9             bharta black                     90.0        60.0      5400.0
# 10    small Green capsicum                      2.0       700.0      1400.0
# ...

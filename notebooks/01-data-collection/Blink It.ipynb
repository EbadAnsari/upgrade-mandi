# %%
import pandas as pd

import camelot

import re
from glob import glob
from pprint import pprint
from datetime import datetime

from typing import List, Tuple
# Out:
# C:\Users\cw\AppData\Roaming\Python\Python311\site-packages\pypdf\_crypt_providers\_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4

# %%
class Extract:
    def __checkColumnName(self, col: pd.Series):
        return (
            col.astype(str)
            .apply(
                lambda string: " ".join(
                    list(
                        filter(
                            lambda x: not x.isspace() and x,
                            string.lower().replace("\n", " ").split(" "),
                        )
                    )
                )
            )
            .isin(list(map(lambda x: x.lower(), self.columns)))
            .any()
        )

    def __init__(self, columns: List[str]):
        self.columns: List[str] = columns
        self.processedDataFrame: pd.DataFrame = pd.DataFrame(columns=self.columns)

    def extractedTableFromPDF(self, filePath):
        pages = camelot.read_pdf(filePath, pages="all")
        df = pd.DataFrame(columns=self.columns)
        for table in pages:
            if len(table.df.columns) >= len(self.columns):
                table.df.columns = self.columns
            df = pd.concat([df, table.df], axis=0, ignore_index=True)
        return df

    def __extractTable(self, row: pd.Series) -> bool:
        return str(row[self.columns[0]]).isnumeric()

    def __extractLabelDate(self, row: str) -> Tuple[List[str], List[datetime]]:
        rawDate = row.split("\n")

        dateFormat = "%d %b, %Y"
        labels, dates = rawDate[:4], [rawDate[4]] + list(
            map(lambda date: datetime.strptime(date, dateFormat), rawDate[5:])
        )

        return (labels, dates)

    def extractDataFrame(self, df: pd.DataFrame):
        labels, dates = self.__extractLabelDate(df.iloc[2, 0])

        df = df[df.columns[df.apply(self.__checkColumnName, axis=0)]].copy()

        df.columns = self.columns
        df = df[df.apply(self.__extractTable, axis=1)].copy()

        for label, date in zip(labels, dates):
            df[label] = date

        return df

    def add(self, dataFrame: pd.DataFrame):
        dataFrame = dataFrame.dropna(how="all", axis=1)
        if not dataFrame.empty:
            self.processedDataFrame = pd.concat(
                [self.processedDataFrame, dataFrame], ignore_index=True
            )

    def save(self, fileName):
        self.processedDataFrame.reset_index(drop=True).to_csv(fileName)

# %%
extract = Extract(
    [
        "Sl No.",
        "Product Name",
        "HSN",
        "Qty. Del.",
        "Price Per Unit",
        "UoM",
        "Total",
    ]
)

extractionError = []

k = 1
for i in glob("./../data/raw/Blink It/*.pdf"):

    print(f"{k}: '{i}'")
    k += 1

    try:
        df = extract.extractedTableFromPDF(i)
        if not df.empty:
            df = extract.extractDataFrame(df)

        if not df.empty:
            extract.add(df)
    except Exception as e:
        extractionError.append((i, e))

extract.processedDataFrame
# Out:
# 1: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1269666-1.pdf'
# 2: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1274368-1.pdf'
# 3: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1276694-1.pdf'
# 4: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1279272-1.pdf'
# 5: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1281280-1.pdf'
# 6: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1283870-1.pdf'
# 7: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1286137-1.pdf'
# 8: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1288444-1.pdf'
# 9: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1291612-1.pdf'
# 10: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1293847-1.pdf'
# 11: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1294697-1.pdf'
# 12: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1295966-1.pdf'
# 13: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1296693-1.pdf'
# 14: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1298679-1.pdf'
# 15: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1300959-1.pdf'
# 16: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1303813-1.pdf'
# 17: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1306159-1.pdf'
# 18: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1308748-1.pdf'
# 19: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1309503-1.pdf'
# 20: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1310923-1.pdf'
# 21: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1313063-1.pdf'
# 22: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1315544-1.pdf'
# 23: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1318159-1.pdf'
# 24: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1319334-1.pdf'
# 25: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1320789-1.pdf'
# 26: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1321537-1.pdf'
# 27: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1323259-1.pdf'
# 28: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1323269-1 (1).pdf'
# 29: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1323269-1.pdf'
# 30: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1325602-1.pdf'
# 31: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1325618-1.pdf'
# 32: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1326787-1.pdf'
# 33: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1327893-1.pdf'
# 34: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1327906-1.pdf'
# 35: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1330151-1.pdf'
# 36: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1330232-1.pdf'
# 37: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1332836-1.pdf'
# 38: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1332840-1.pdf'
# 39: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1335331-1.pdf'
# 40: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1335693-1.pdf'
# 41: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1336345-1.pdf'
# 42: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1338211-1.pdf'
# 43: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1340676-1.pdf'
# 44: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1341925-1.pdf'
# 45: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1342926-1.pdf'
# 46: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1347489-1.pdf'
# 47: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1349975-1.pdf'
# 48: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1352526-1.pdf'
# 49: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1355936-1.pdf'
# 50: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1357263-1.pdf'
# 51: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1359757-1.pdf'
# 52: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1361923-1.pdf'
# 53: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1364176-1.pdf'
# 54: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1366628-1.pdf'
# 55: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1371083-1.pdf'
# 56: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1372026-1.pdf'
# 57: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1374808-1.pdf'
# 58: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1377305-1.pdf'
# 59: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1379541-1.pdf'
# 60: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1381743-1.pdf'
# 61: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1384574-1.pdf'
# 62: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1386433-1.pdf'
# 63: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1388984-1.pdf'
# 64: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1391578-1.pdf'
# 65: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1394135-1.pdf'
# 66: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1396369-1.pdf'
# 67: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1398408-1.pdf'
# 68: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1398891-1.pdf'
# 69: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1401205-1.pdf'
# 70: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1403816-1.pdf'
# 71: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1406301-1.pdf'
# 72: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1409340-1.pdf'
# 73: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1410605-1.pdf'
# 74: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1410605-2.pdf'
# 75: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1411919-1.pdf'
# 76: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1413212-1.pdf'
# 77: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1414391-1.pdf'
# 78: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1414700-1.pdf'
# 79: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1416629-1.pdf'
# 80: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1419545-1.pdf'
# 81: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1422314-1.pdf'
# 82: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1425081-1.pdf'
# 83: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1427810-1.pdf'
# 84: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1430737-1.pdf'
# 85: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1433222-1.pdf'
# 86: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1435532-1.pdf'
# 87: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1438375-1.pdf'
# 88: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1441280-1.pdf'
# 89: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1444138-1.pdf'
# 90: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1446805-1.pdf'
# 91: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1449624-1.pdf'
# 92: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1452154-1.pdf'
# 93: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1454747-1.pdf'
# 94: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1455612-1.pdf'
# 95: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1457511-1.pdf'
# 96: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1460289-1.pdf'
# 97: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1462921-1.pdf'
# 98: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1463502-1.pdf'
# 99: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1465695-1.pdf'
# 100: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1468328-1.pdf'
# 101: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1470780-1.pdf'
# 102: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1471400-1.pdf'
# 103: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1473321-1.pdf'
# 104: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1476486-1.pdf'
# 105: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1476567-1.pdf'
# 106: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1479174-1.pdf'
# 107: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1479540-1.pdf'
# 108: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1481820-1.pdf'
# 109: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1482259-1.pdf'
# 110: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1484570-1.pdf'
# 111: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1485140-1.pdf'
# 112: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1485423-1.pdf'
# 113: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1487265-1.pdf'
# 114: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1489848-1.pdf'
# 115: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1490342-1.pdf'
# 116: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1492227-1.pdf'
# 117: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1495234-1.pdf'
# 118: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1497948-1.pdf'
# 119: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1500605-1.pdf'
# 120: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1503447-1.pdf'
# 121: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1506284-1.pdf'
# 122: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1508673-1.pdf'
# 123: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1510891-1.pdf'
# 124: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1513957-1.pdf'
# 125: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1517146-1.pdf'
# 126: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1520155-1.pdf'
# 127: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1522206-1.pdf'
# 128: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1524969-1.pdf'
# 129: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1527244-1.pdf'
# 130: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1529519-1.pdf'
# 131: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1532557-1.pdf'
# 132: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1533069-1.pdf'
# 133: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1535398-1.pdf'
# 134: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1535440-1.pdf'
# 135: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1538200-1.pdf'
# 136: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1538201-1.pdf'
# 137: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1540997-1.pdf'
# 138: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1543689-1.pdf'
# 139: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1543724-1.pdf'
# 140: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1546142-1.pdf'
# 141: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1546145-1.pdf'
# 142: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1548414-1.pdf'
# 143: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1548417-1.pdf'
# 144: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1551436-1.pdf'
# 145: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1551490-1.pdf'
# 146: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1554119-1.pdf'
# 147: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1554224-1.pdf'
# 148: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1557045-1.pdf'
# 149: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1560083-1.pdf'
# 150: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1560113-1.pdf'
# 151: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1562675-1.pdf'
# 152: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1562784-1.pdf'
# 153: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1565077-1.pdf'
# 154: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1565099-1.pdf'
# 155: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1567364-1.pdf'
# 156: './../data/raw/Blink It\Invoice-CPCMH25-GRN-1567492-1.pdf'
# 157: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1570449-1.pdf'
# 158: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1570461-1.pdf'
# 159: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1573292-1.pdf'
# 160: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1576063-1.pdf'
# 161: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1579030-1.pdf'
# 162: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1581975-1.pdf'
# 163: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1584616-1.pdf'
# 164: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1587087-1.pdf'
# 165: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1587090-1.pdf'
# 166: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1590125-1.pdf'
# 167: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1590128-1.pdf'
# 168: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1593143-1.pdf'
# 169: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1596124-1.pdf'
# 170: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1596128-1.pdf'
# 171: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1599075-1.pdf'
# 172: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1602106-1.pdf'
# 173: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1602108-1.pdf'
# 174: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1604950-1.pdf'
# 175: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1604953-1.pdf'
# 176: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1607422-1.pdf'
# 177: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1607436-1.pdf'
# 178: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1610550-1.pdf'
# 179: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1610555-1.pdf'
# 180: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1613650-1.pdf'
# 181: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1613658-1.pdf'
# 182: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1616801-1.pdf'
# 183: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1616803-1.pdf'
# 184: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1619919-1.pdf'
# 185: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1622909-1.pdf'
# 186: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1622911-1.pdf'
# 187: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1625617-1.pdf'
# 188: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1625619-1.pdf'
# 189: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1628113-1.pdf'
# 190: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1628115-1.pdf'
# 191: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1629343-1.pdf'
# 192: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1631446-1.pdf'
# 193: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1631447-1.pdf'
# 194: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1634709-1.pdf'
# 195: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1634713-1.pdf'
# 196: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1637785-1.pdf'
# 197: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1638892-1.pdf'
# 198: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1641121-1.pdf'
# 199: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1644259-1.pdf'
# 200: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1647151-1.pdf'
# 201: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1647159-1.pdf'
# 202: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1647927-1.pdf'
# 203: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1649726-1.pdf'
# 204: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1649732-1.pdf'
# 205: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1653102-1.pdf'
# 206: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1653111-1.pdf'
# 207: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1654306-1.pdf'
# 208: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1656179-1.pdf'
# 209: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1656190-1.pdf'
# 210: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1659257-1.pdf'
# 211: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1659259-1.pdf'
# 212: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1662589-1.pdf'
# 213: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1666354-1.pdf'
# 214: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1666357-1.pdf'
# 215: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1667170-1.pdf'
# 216: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1669215-1.pdf'
# 217: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1669231-1.pdf'
# 218: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1672144-1.pdf'
# 219: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1672147-1.pdf'
# 220: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1675614-1.pdf'
# 221: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1675620-1.pdf'
# 222: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1679006-1.pdf'
# 223: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1679010-1.pdf'
# 224: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1682230-1.pdf'
# 225: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1682237-1.pdf'
# 226: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1682617-1.pdf'
# 227: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1685641-1.pdf'
# 228: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1685648-1.pdf'
# 229: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1689087-1.pdf'
# 230: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1689093-1.pdf'
# 231: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1691993-1.pdf'
# 232: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1691998-1.pdf'
# 233: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1694635-1.pdf'
# 234: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1694643-1.pdf'
# 235: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1695233-1.pdf'
# 236: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1697992-1.pdf'
# 237: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1697997-1.pdf'
# 238: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1701658-1.pdf'
# 239: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1701666-1.pdf'
# 240: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1705019-1.pdf'
# 241: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1705024-1.pdf'
# 242: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1708467-1.pdf'
# 243: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1708472-1.pdf'
# 244: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1711801-1.pdf'
# 245: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1711804-1.pdf'
# 246: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1712272-1.pdf'
# 247: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1714625-1.pdf'
# 248: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1714631-1.pdf'
# 249: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1717283-1.pdf'
# 250: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1717289-1.pdf'
# 251: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1720747-1.pdf'
# 252: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1720755-1.pdf'
# 253: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1724126-1.pdf'
# 254: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1724126-2.pdf'
# 255: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1724133-1.pdf'
# 256: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1727241-1.pdf'
# 257: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1727246-1.pdf'
# 258: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1727246-2.pdf'
# 259: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1730616-1.pdf'
# 260: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1730622-1.pdf'
# 261: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1731117-1.pdf'
# 262: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1733947-1.pdf'
# 263: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1733947-2.pdf'
# 264: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1733949-1.pdf'
# 265: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1736961-1.pdf'
# 266: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1736966-1.pdf'
# 267: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1737316-1.pdf'
# 268: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1739640-1.pdf'
# 269: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1739640-2.pdf'
# 270: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1739644-1.pdf'
# 271: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1743046-1.pdf'
# 272: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1743049-1.pdf'
# 273: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1746529-1.pdf'
# 274: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1746536-1.pdf'
# 275: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1749944-1.pdf'
# 276: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1749948-1.pdf'
# 277: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1753340-1.pdf'
# 278: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1753343-1.pdf'
# 279: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1756705-1.pdf'
# 280: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1756710-1.pdf'
# 281: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1757579-1.pdf'
# 282: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1759988-1.pdf'
# 283: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1759995-1.pdf'
# 284: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1762787-1.pdf'
# 285: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1762794-1.pdf'
# 286: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1763460-1.pdf'
# 287: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1766498-1.pdf'
# 288: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1766504-1.pdf'
# 289: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1769973-1.pdf'
# 290: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1769978-1.pdf'
# 291: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1773361-1 (1).pdf'
# 292: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1773361-1.pdf'
# 293: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1773364-1.pdf'
# 294: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1776895-1.pdf'
# 295: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1776899-1.pdf'
# 296: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1780213-1.pdf'
# 297: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1780221-1.pdf'
# 298: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1783187-1.pdf'
# 299: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1783190-1.pdf'
# 300: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1783534-1.pdf'
# 301: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1785948-1.pdf'
# 302: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1785951-1.pdf'
# 303: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1789612-1.pdf'
# 304: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1789620-1.pdf'
# 305: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1790202-1.pdf'
# 306: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1793075-1.pdf'
# 307: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1793075-2.pdf'
# 308: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1793082-1.pdf'
# 309: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1793609-1.pdf'
# 310: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1796182-1.pdf'
# 311: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1796570-1.pdf'
# 312: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1796572-1.pdf'
# 313: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1797186-1.pdf'
# 314: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1797412-1.pdf'
# 315: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1799534-1.pdf'
# 316: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1800101-1.pdf'
# 317: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1800105-1.pdf'
# 318: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1800680-1.pdf'
# 319: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1800708-1.pdf'
# 320: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1803609-1.pdf'
# 321: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1803611-1.pdf'
# 322: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1804198-1.pdf'
# 323: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1804203-1.pdf'
# 324: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1806887-1.pdf'
# 325: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1807636-1.pdf'
# 326: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1807644-1.pdf'
# 327: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1807644-2.pdf'
# 328: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1808108-1.pdf'
# 329: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1810250-1.pdf'
# 330: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1810731-1.pdf'
# 331: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1810737-1.pdf'
# 332: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1811485-1.pdf'
# 333: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1814172-1.pdf'
# 334: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1814732-1.pdf'
# 335: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1814735-1.pdf'
# 336: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1817761-1.pdf'
# 337: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1818527-1.pdf'
# 338: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1818534-1.pdf'
# 339: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1820707-1.pdf'
# 340: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1822151-1.pdf'
# 341: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1822151-3.pdf'
# 342: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1822158-1.pdf'
# 343: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1825311-1.pdf'
# 344: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1826066-1.pdf'
# 345: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1826074-1.pdf'
# 346: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1826576-1.pdf'
# 347: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1828648-1.pdf'
# 348: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1829724-1.pdf'
# 349: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1829724-2.pdf'
# 350: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1829726-1.pdf'
# 351: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1832467-1.pdf'
# 352: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1833311-1.pdf'
# 353: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1833313-1.pdf'
# 354: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1835171-1.pdf'
# 355: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1836463-1.pdf'
# 356: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1836467-1.pdf'
# 357: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1837059-1.pdf'
# 358: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1839279-1.pdf'
# 359: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1840403-1.pdf'
# 360: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1840412-1.pdf'
# 361: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1840952-1.pdf'
# 362: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1844219-1.pdf'
# 363: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1844225-1.pdf'
# 364: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1847188-1.pdf'
# 365: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1848059-1.pdf'
# 366: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1848063-1.pdf'
# 367: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1848426-1.pdf'
# 368: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1850921-1.pdf'
# 369: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1851897-1.pdf'
# 370: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1851897-2.pdf'
# 371: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1851903-1.pdf'
# 372: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1852529-1.pdf'
# 373: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1854403-1.pdf'
# 374: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1855794-1.pdf'
# 375: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1855798-1.pdf'
# 376: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1857539-1.pdf'
# 377: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1859131-1.pdf'
# 378: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1859145-1.pdf'
# 379: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1859147-1.pdf'
# 380: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1861293-1.pdf'
# 381: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1862347-1.pdf'
# 382: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1862354-1.pdf'
# 383: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1865592-1.pdf'
# 384: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1866158-1.pdf'
# 385: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1866158-2.pdf'
# 386: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1866160-1.pdf'
# 387: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1869859-1.pdf'
# 388: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1869868-1.pdf'
# 389: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1873811-1.pdf'
# 390: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1873815-1.pdf'
# 391: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1876535-1.pdf'
# 392: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1877807-1.pdf'
# 393: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1877819-1.pdf'
# 394: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1880458-1.pdf'
# 395: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1880510-1.pdf'
# 396: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1881537-1.pdf'
# 397: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1881542-1.pdf'
# 398: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1884249-1.pdf'
# 399: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1885133-1.pdf'
# 400: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1885137-1.pdf'
# 401: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1887584-1.pdf'
# 402: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1888399-1.pdf'
# 403: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1888405-1.pdf'
# 404: './../data/raw/Blink It\Invoice-CPCMH26-GRN-1888405-2.pdf'
#      Sl No.                                       Product Name       HSN  \
# 0         1  BH-Baby Bottle Gourd\nSmall, 1 Piece (250 - 35...  07099390
# 1         2      BH - Fresh Cabbage, 400\ngm - 600 gm (1 Unit)  07049000
# 2         3           BH - Cauliflower, 1 Unit\n(400 - 600 gm)  07041000
# 3         4                      BH-Desi Tomato, 505 -\n515 gm  07020000
# 4         5                BH - Fresh Garlic\n(Lehsun), 200 gm  07049000
# ...     ...                                                ...       ...
# 8896      3      BH - Fresh Cabbage, 400\ngm - 600 gm (1 Unit)  07049000
# 8897      4        BH - Cauliflower, 300 gm\n- 500 gm (1 Unit)  07031010
# 8898      5           BH - Fresh Green\nCapsicum, 250 - 280 gm  07041000
# 8899      6        BH - Fresh Cucumber\n(Kheera), 500 - 700 gm  07049000
# 8900      7                    BH-Orange Carrot, 200 -\n250 gm  07061000
#
#      Qty. Del. Price Per Unit        UoM       Total  Invoice Number  \
# 0           14           11.5   Kilogram    ₹ 161.00    2025/18238/1
# 1           31             18  Per piece    ₹ 558.00    2025/18238/1
# 2           31             18  Per piece    ₹ 558.00    2025/18238/1
# 3           32             31      Count    ₹ 992.00    2025/18238/1
# 4           19             96      Count   ₹ 1824.00    2025/18238/1
# ...        ...            ...        ...         ...             ...
# 8896       209             18  Per piece   ₹ 3762.00  2026/18238/227
# 8897       170             47      Count   ₹ 7990.00  2026/18238/227
# 8898       277           23.5      Count   ₹ 6509.50  2026/18238/227
# 8899       506           18.8      Count   ₹ 9512.80  2026/18238/227
# 8900       465             22      Count  ₹ 10230.00  2026/18238/227
#
#      Order Date Invoice Date Delivery Date
# 0    2024-12-05   2024-12-05    2024-12-05
# 1    2024-12-05   2024-12-05    2024-12-05
# 2    2024-12-05   2024-12-05    2024-12-05
# 3    2024-12-05   2024-12-05    2024-12-05
# 4    2024-12-05   2024-12-05    2024-12-05
# ...         ...          ...           ...
# 8896 2025-06-29   2025-06-29    2025-06-29
# 8897 2025-06-29   2025-06-29    2025-06-29
# 8898 2025-06-29   2025-06-29    2025-06-29
# 8899 2025-06-29   2025-06-29    2025-06-29
# 8900 2025-06-29   2025-06-29    2025-06-29
#
# [8901 rows x 11 columns]

# %%
extract.processedDataFrame.reset_index(drop=True).to_csv(
    "./../data/cleaned/Blinkit.csv",
)

# %%
import re
from collections import Counter
from datetime import datetime
from glob import glob
from math import floor
from os.path import join
from pprint import pprint
from typing import List, Tuple

import numpy as np
import pandas as pd

# %%
def nameExtracter(rightNamesList: List[str], wrongName: str) -> str:
    chances = [0] * len(rightNamesList)

    counterOriginal = Counter(wrongName.lower())
    for i, rightName in enumerate(rightNamesList):
        counterLocation = Counter(rightName.lower())
        chances[i] = (
            sum((counterOriginal & counterLocation).values())
            * 2
            / (sum(counterOriginal.values()) + sum(counterLocation.values()))
        )
    return rightNamesList[chances.index(max(chances))]


prev = 0


def pretty(label: str, completed: float, total: int, length: int = 30) -> None:
    global prev
    print(
        " " * prev * 2
        + f"\r{label} ["
        + "=" * int(completed / total * length)
        + "-" * int((total - completed) / total * length)
        + f"] {int(completed / total * 100)}%",
        end="",
    )
    prev = length


def generateInvoiceId(date: datetime, locationCode: str, invoiceVersion: int):
    return f'{date.strftime("%d%m%Y")}U{locationCode}{invoiceVersion}'


def generatePONo(date: datetime, storeId: str, supplierId: str):
    return f'{date.strftime("%Y%m%d")}-{storeId}-{supplierId}'

# %% [markdown]
# ##### Hard Code

# %%
RAW_FOLDER_PATH = "./../../upgrade_mandi/data/raw"
CLEANED_FOLDER_PATH = "./../../upgrade_mandi/data/cleaned"

SWIGGY_RAW = join(RAW_FOLDER_PATH, "swiggy")

domains = {
    "Swiggy": {
        "path": {
            "raw": "swiggy",
            "cleand": "swiggy",
        },
        "input-columns": [
            "Article Code",
            "Item Description",
            "UoM",
            "Dispatched Qty",
            "Rate",
            "Total Amount",
        ],
        "output-columns": [
            "Sr",
            "Article Code",
            "Item Description",
            "UoM",
            "Dispatched Qty",
            "Recieved Qty",
            "Rate",
            "Total Amount",
        ],
        "locations": {
            "Ayodhya Nagar": {
                "shipping-address": "Gadewar Lawns Plot No.31; 32; 33; 36; 37 And 38; K. H. No; 72/2; Situated At Gadewar Lawn; Shri Ram Wadi",
                "retailer": "Rajidi Retail Pvt Ltd",
                "code": "AN",
                "storeId": "1403419",
            },
            "Byramji": {
                "shipping-address": "Unit nos - 59 to 71 Lower Ground Floor Ginger Square' City Survey No - 1049",
                "retailer": "Rajidi Retail Pvt Ltd",
                "code": "B",
                "storeId": "1392084",
            },
            "Dharampeth": {
                "shipping-address": "Plot No. 151; CTS No. 135 Puja Sabhagrah; Ravi Nagar Square; Ram Nagar",
                "retailer": "Swinsta Ent Private Limited",
                "code": "DH",
                "storeId": "1397624",
            },
            "Mahal": {
                "shipping-address": "Unit no - G-1; Plot no.58; sardar patel timber Dhantoli; NAGPUR- 440027",
                "retailer": "Rajidi Retail Pvt Ltd",
                "code": "MH",
                "storeId": "1393571",
            },
            "Manish Nagar": {
                "shipping-address": "Ground floor 'Jayanti Mansion III; Manish nagar  Nagpur Maharashtra",
                "retailer": "Rajidi Retail Pvt Ltd",
                "code": "MN",
                "storeId": "1392532",
            },
            "Nandanvan": {
                "shipping-address": "Vinayak Tower; Lower Ground Floor; Survey No.212 Gurudev Nagar Main Road; New Nanadanvan",
                "retailer": "Swinsta Ent Private Limited",
                "code": "NA",
                "storeId": "1397035",
            },
            "Sai Mandir": {
                "shipping-address": "Khasra No 18/2; city Survey No.718; House No. 781/B; Situated at Village Ajni",
                "retailer": "Swinsta Ent Private Limited",
                "code": "S",
                "storeId": "1399707",
            },
        },
    },
    "Zepto": {
        "path": {
            "raw": "zepto",
            "cleand": "zepto",
        },
        "input-columns": [
            "No",
            "Article Name",
            "UoM",
            "Invoice Qty.",
            "Rate",
            "Amount",
        ],
        "locations": {
            "Gokulpeth": {"shipping-address": "", "retailer": "Dorgheria"},
            "Mahada": {"shipping-address": "", "retailer": "Dorgheria"},
            "Khamla": {"shipping-address": "", "retailer": "Dorgheria"},
            "Garoba Maidan": {"shipping-address": "", "retailer": "Dorgheria"},
            "Raghuji Nagar": {"shipping-address": "", "retailer": "Dorgheria"},
            "Zingabai Takli": {"shipping-address": "", "retailer": "Dorgheria"},
            "Bhupesh Nagar": {"shipping-address": "", "retailer": "Dorgheria"},
            "Besa": {"shipping-address": "", "retailer": "Dorgheria"},
        },
    },
}

# %% [markdown]
# ##### Imports

# %%
excelBooks: dict[str, List[dict[str, pd.DataFrame]]] = {
    domain: [
        pd.read_excel(path, sheet_name=None)
        for path in glob(
            join(RAW_FOLDER_PATH, domains[domain]["path"]["raw"], "*.xlsx")
        )
    ]
    for domain in domains
}

print(
    f"Found {len(excelBooks)} domains with {sum([len(excelBooks[domain]) for domain in excelBooks])} files."
)

pprint(
    {
        domain: [
            path
            for path in glob(
                join(RAW_FOLDER_PATH, domains[domain]["path"]["raw"], "*.xlsx")
            )
        ]
        for domain in domains
    }
)
# Out:
# Found 2 domains with 4 files.
# {'Swiggy': ['./../../upgrade_mandi/data/raw\\swiggy\\Swiggy 09-04-2025 to  '
#             '22-06-2025.xlsx',
#             './../../upgrade_mandi/data/raw\\swiggy\\Swiggy 22-06-2025 to '
#             'Current.xlsx',
#             './../../upgrade_mandi/data/raw\\swiggy\\Swiggy 28-01-2025 to '
#             '08-04-2025.xlsx'],
#  'Zepto': ['./../../upgrade_mandi/data/raw\\zepto\\Zepto 10-07-2025 - '
#            '20-06-2025.xlsx']}

# %% [markdown]
# ##### Extractor

# %%
class Extract:
    def __checkColumnName(self, col: pd.Series):
        return (
            col.astype(str)
            .apply(
                lambda string: " ".join(
                    list(
                        filter(
                            lambda x: not x.isspace() and x,
                            string.lower().replace("\n", "").split(" "),
                        )
                    )
                )
            )
            .isin(list(map(lambda x: x.lower(), self.columns)))
            .any()
        )

    def __extractTable(self, row: pd.Series) -> bool:
        return str(row[self.columns[0]]).isnumeric()

    def __extractDateLocation(self, rawString: str) -> Tuple[datetime, str] | False:
        datePattern = "^(\d){1,2}[-/](\d){1,2}[-/](\d){4}"
        dateMached = re.match(datePattern, rawString)

        if dateMached:
            dateFormat = "%d-%m-%Y"
            date = datetime.strptime(
                re.sub(r"[-/]", "-", dateMached.group(0)), dateFormat
            ).strftime("%m-%d-%Y")

            area = nameExtracter(
                list(self.locations.keys()),
                rawString,
            ).title()

            return (date, area)
        return (False, False)

    # dict[str, dict[str, str]]
    def __init__(self, columns: List[str], locations: dict, vendorName: str):
        self.columns: List[str] = columns
        self.locations = locations
        self.vendorName = vendorName

        self.locationParsed = {x: [] for x in self.locations}
        self.processedDataFrame: pd.DataFrame = pd.DataFrame(columns=self.columns)

    def extractDataFrame(self, sheetName: str, sheetData: pd.DataFrame):
        # sheetData.columns = self.columns[:-2]
        date, location = self.__extractDateLocation(sheetName)
        if date == False:
            return pd.DataFrame()

        sheetData = sheetData[
            sheetData.columns[sheetData.apply(self.__checkColumnName, axis=0)]
        ].copy()

        sheetData.columns = self.columns
        sheetData = sheetData[sheetData.apply(self.__extractTable, axis=1)].copy()

        invoiceVersion = 1
        numbers = re.findall(r"\d+(?:\.\d+)?", sheetName[11:])
        if numbers:
            invoiceVersion = int(numbers[0])

        sheetData["Date"] = date
        sheetData["Location"] = location
        sheetData["Invoice Version"] = invoiceVersion
        sheetData["Retailer"] = self.locations[location]["retailer"]
        sheetData["Vendor Name"] = self.vendorName
        sheetData["Shipping Address"] = self.locations[location]["shipping-address"]
        sheetData["PO No"] = generatePONo(
            datetime.strptime(date, "%m-%d-%Y"),
            self.locations[location]["storeId"],
            "74227878",
        )

        sheetData["Invoice Version"].astype(int)

        self.locationParsed[location].append(sheetName)

        return sheetData

    def add(self, dataFrame: pd.DataFrame):
        dataFrame = dataFrame.dropna(how="all", axis=1)
        if not dataFrame.empty:
            self.processedDataFrame = pd.concat(
                [self.processedDataFrame, dataFrame], ignore_index=True
            )

    def save(self, fileName, split=-1):
        self.processedDataFrame.iloc[: len(self.processedDataFrame) // 2].to_csv(
            f"{fileName} 0.csv", index=False
        )
        self.processedDataFrame.iloc[
            (len(self.processedDataFrame) // 2) : len(self.processedDataFrame)
        ].to_csv(f"{fileName} 1.csv", index=False)

# %% [markdown]
# ##### Run

# %%
extractedDomains: dict[str, pd.DataFrame] = {}

errorSheets: dict[str, List[str]] = {domain: [] for domain in domains}

for domain in domains:
    if domain == "Zepto":
        continue

    extract = Extract(
        domains[domain]["input-columns"],
        domains[domain]["locations"],
        "Upgrade Mandi",
    )
    for excelBook in excelBooks[domain]:
        count = 0
        for sheetName, sheetData in excelBook.items():
            if sheetData.empty:
                errorSheets[domain].append(sheetName)
                continue

            df = extract.extractDataFrame(sheetName, sheetData)
            try:
                if not df.empty:
                    extract.add(df)
                else:
                    errorSheets[domain].append(sheetName)
            except:
                errorSheets[domain].append(sheetName)
                break
            count += 1
            pretty(domain, count, len(excelBook), 30)
        print()
    print(f"Processed {domain} data.\n")

    extractedDomains[domain] = extract

print("The following sheets are not parsed: ")
pprint(errorSheets)
# Out:
# Swiggy [==============================] 100%
# Swiggy [==============================] 100%
# Swiggy [==============================] 100%
# Processed Swiggy data.
#
# The following sheets are not parsed:
# {'Swiggy': [], 'Zepto': []}

# %%
for domain in extractedDomains:
    extractedDomains[domain].save(join(CLEANED_FOLDER_PATH, domain.lower(), domain), 2)

# %%
extractedDomains["Swiggy"].processedDataFrame[
    extractedDomains["Swiggy"].processedDataFrame["Date"] == "06-21-2025"
]
# Out:
#    Article Code         Item Description      UoM Dispatched Qty Rate  \
# 23         8439              Beans Diced     200g              2   40
# 24         4074      Cauliflower Florets     200g             11   30
# 25         9013  Ladies Finger - Fry Cut     200g              6   20
# 26         4068              Pumpkin Cut     200g              5   20
# 27         8439              Beans Diced     200g              1   40
# 28         4074      Cauliflower Florets     200g              4   30
# 29         9013  Ladies Finger - Fry Cut     200g              2   20
# 30         4068              Pumpkin Cut     200g              3   20
# 31         8439              Beans Diced     200g              1   40
# 32         4074      Cauliflower Florets     200g              1   30
# 33         9013  Ladies Finger - Fry Cut     200g              1   20
# 34         4068              Pumpkin Cut     200g              1   20
# 35         1113              Ridge Gourd  2pieces              2   30
# 36         8439              Beans Diced     200g              3   40
# 37         4074      Cauliflower Florets     200g              8   30
# 38         9013  Ladies Finger - Fry Cut     200g              8   20
# 39         4068              Pumpkin Cut     200g              7   20
# 40         8439              Beans Diced     200g              1   40
# 41         4074      Cauliflower Florets     200g              7   30
# 42         9013  Ladies Finger - Fry Cut     200g              2   20
# 43         4068              Pumpkin Cut     200g              4   20
# 44         4068              Pumpkin Cut     200g              2   20
# 45         8439              Beans Diced     200g              1   40
# 46         7043           Brinjal Nagpur     300g              2   20
# 47         4074      Cauliflower Florets     200g              3   30
# 48        15024           Kateri Brinjal     250g              2   12
# 49         9013  Ladies Finger - Fry Cut     200g              2   20
# 50         4068              Pumpkin Cut     200g              1   20
#
#    Total Amount        Date       Location  Invoice Version  \
# 23           80  06-21-2025   Manish Nagar              1.0
# 24          330  06-21-2025   Manish Nagar              1.0
# 25          120  06-21-2025   Manish Nagar              1.0
# 26          100  06-21-2025   Manish Nagar              1.0
# 27           40  06-21-2025     Dharampeth              1.0
# 28          120  06-21-2025     Dharampeth              1.0
# 29           40  06-21-2025     Dharampeth              1.0
# 30           60  06-21-2025     Dharampeth              1.0
# 31           40  06-21-2025  Ayodhya Nagar              1.0
# 32           30  06-21-2025  Ayodhya Nagar              1.0
# 33           20  06-21-2025  Ayodhya Nagar              1.0
# 34           20  06-21-2025  Ayodhya Nagar              1.0
# 35           60  06-21-2025  Ayodhya Nagar              1.0
# 36          120  06-21-2025        Byramji              1.0
# 37          240  06-21-2025        Byramji              1.0
# 38          160  06-21-2025        Byramji              1.0
# 39          140  06-21-2025        Byramji              1.0
# 40           40  06-21-2025      Nandanvan              1.0
# 41          210  06-21-2025      Nandanvan              1.0
# 42           40  06-21-2025      Nandanvan              1.0
# 43           80  06-21-2025      Nandanvan              1.0
# 44           40  06-21-2025          Mahal              1.0
# 45           40  06-21-2025     Sai Mandir              1.0
# 46           40  06-21-2025     Sai Mandir              1.0
# 47           90  06-21-2025     Sai Mandir              1.0
# 48           24  06-21-2025     Sai Mandir              1.0
# 49           40  06-21-2025     Sai Mandir              1.0
# 50           20  06-21-2025     Sai Mandir              1.0
#
#                        Retailer    Vendor Name  \
# 23        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 24        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 25        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 26        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 27  Swinsta Ent Private Limited  Upgrade Mandi
# 28  Swinsta Ent Private Limited  Upgrade Mandi
# 29  Swinsta Ent Private Limited  Upgrade Mandi
# 30  Swinsta Ent Private Limited  Upgrade Mandi
# 31        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 32        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 33        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 34        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 35        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 36        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 37        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 38        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 39        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 40  Swinsta Ent Private Limited  Upgrade Mandi
# 41  Swinsta Ent Private Limited  Upgrade Mandi
# 42  Swinsta Ent Private Limited  Upgrade Mandi
# 43  Swinsta Ent Private Limited  Upgrade Mandi
# 44        Rajidi Retail Pvt Ltd  Upgrade Mandi
# 45  Swinsta Ent Private Limited  Upgrade Mandi
# 46  Swinsta Ent Private Limited  Upgrade Mandi
# 47  Swinsta Ent Private Limited  Upgrade Mandi
# 48  Swinsta Ent Private Limited  Upgrade Mandi
# 49  Swinsta Ent Private Limited  Upgrade Mandi
# 50  Swinsta Ent Private Limited  Upgrade Mandi
#
#                                      Shipping Address  \
# 23  Ground floor 'Jayanti Mansion III; Manish naga...
# 24  Ground floor 'Jayanti Mansion III; Manish naga...
# 25  Ground floor 'Jayanti Mansion III; Manish naga...
# 26  Ground floor 'Jayanti Mansion III; Manish naga...
# 27  Plot No. 151; CTS No. 135 Puja Sabhagrah; Ravi...
# 28  Plot No. 151; CTS No. 135 Puja Sabhagrah; Ravi...
# 29  Plot No. 151; CTS No. 135 Puja Sabhagrah; Ravi...
# 30  Plot No. 151; CTS No. 135 Puja Sabhagrah; Ravi...
# 31  Gadewar Lawns Plot No.31; 32; 33; 36; 37 And 3...
# 32  Gadewar Lawns Plot No.31; 32; 33; 36; 37 And 3...
# 33  Gadewar Lawns Plot No.31; 32; 33; 36; 37 And 3...
# 34  Gadewar Lawns Plot No.31; 32; 33; 36; 37 And 3...
# 35  Gadewar Lawns Plot No.31; 32; 33; 36; 37 And 3...
# 36  Unit nos - 59 to 71 Lower Ground Floor Ginger ...
# 37  Unit nos - 59 to 71 Lower Ground Floor Ginger ...
# 38  Unit nos - 59 to 71 Lower Ground Floor Ginger ...
# 39  Unit nos - 59 to 71 Lower Ground Floor Ginger ...
# 40  Vinayak Tower; Lower Ground Floor; Survey No.2...
# 41  Vinayak Tower; Lower Ground Floor; Survey No.2...
# 42  Vinayak Tower; Lower Ground Floor; Survey No.2...
# 43  Vinayak Tower; Lower Ground Floor; Survey No.2...
# 44  Unit no - G-1; Plot no.58; sardar patel timber...
# 45  Khasra No 18/2; city Survey No.718; House No. ...
# 46  Khasra No 18/2; city Survey No.718; House No. ...
# 47  Khasra No 18/2; city Survey No.718; House No. ...
# 48  Khasra No 18/2; city Survey No.718; House No. ...
# 49  Khasra No 18/2; city Survey No.718; House No. ...
# 50  Khasra No 18/2; city Survey No.718; House No. ...
#
#                         PO No
# 23  20250621-1392532-74227878
# 24  20250621-1392532-74227878
# 25  20250621-1392532-74227878
# 26  20250621-1392532-74227878
# 27  20250621-1397624-74227878
# 28  20250621-1397624-74227878
# 29  20250621-1397624-74227878
# 30  20250621-1397624-74227878
# 31  20250621-1403419-74227878
# 32  20250621-1403419-74227878
# 33  20250621-1403419-74227878
# 34  20250621-1403419-74227878
# 35  20250621-1403419-74227878
# 36  20250621-1392084-74227878
# 37  20250621-1392084-74227878
# 38  20250621-1392084-74227878
# 39  20250621-1392084-74227878
# 40  20250621-1397035-74227878
# 41  20250621-1397035-74227878
# 42  20250621-1397035-74227878
# 43  20250621-1397035-74227878
# 44  20250621-1393571-74227878
# 45  20250621-1399707-74227878
# 46  20250621-1399707-74227878
# 47  20250621-1399707-74227878
# 48  20250621-1399707-74227878
# 49  20250621-1399707-74227878
# 50  20250621-1399707-74227878

# %% [markdown]
# ##### Test

# %%
import re
from collections import Counter
from datetime import datetime
from glob import glob
from math import floor
from os.path import join
from pprint import pprint
from typing import List, Tuple

from utils.config import domainConfigClass

import numpy as np
import pandas as pd

# %%
def nameExtracter(rightNamesList: List[str], wrongName: str) -> str:
    chances = [0] * len(rightNamesList)

    counterOriginal = Counter(wrongName.lower())
    for i, rightName in enumerate(rightNamesList):
        counterLocation = Counter(rightName.lower())
        chances[i] = (
            sum((counterOriginal & counterLocation).values())
            * 2
            / (sum(counterOriginal.values()) + sum(counterLocation.values()))
        )
    return rightNamesList[chances.index(max(chances))]


prev = 0


def pretty(label: str, completed: float, total: int, length: int = 30) -> None:
    global prev
    print(
        " " * prev * 2
        + f"\r{label} ["
        + "=" * int(completed / total * length)
        + "-" * int((total - completed) / total * length)
        + f"] {int(completed / total * 100)}%",
        end="",
    )
    prev = length


def generateInvoiceId(date: datetime, locationCode: str, invoiceVersion: int):
    return f'{date.strftime("%d%m%Y")}U{locationCode}{invoiceVersion}'


def generatePONo(date: datetime, storeId: str, supplierId: str):
    return f'{date.strftime("%Y%m%d")}-{storeId}-{supplierId}'

# %% [markdown]
# ##### Hard Code

# %%
RAW_FOLDER_PATH = "./../../upgrade_mandi/data/raw"
CLEANED_FOLDER_PATH = "./../../upgrade_mandi/data/cleaned"

SWIGGY_RAW = join(RAW_FOLDER_PATH, "swiggy")

domains = {
    "Swiggy": {
        "path": {
            "raw": "swiggy",
            "cleand": "swiggy",
        },
        "input-columns": [
            "Article Code",
            "Item Description",
            "UoM",
            "Dispatched Qty",
            "Rate",
            "Total Amount",
        ],
        "output-columns": [
            "Sr",
            "Article Code",
            "Item Description",
            "UoM",
            "Dispatched Qty",
            "Recieved Qty",
            "Rate",
            "Total Amount",
        ],
        "locations": {
            "Ayodhya Nagar": {
                "shipping-address": "Gadewar Lawns Plot No.31; 32; 33; 36; 37 And 38; K. H. No; 72/2; Situated At Gadewar Lawn; Shri Ram Wadi",
                "retailer": "Rajidi Retail Pvt Ltd",
                "code": "AN",
                "storeId": "1403419",
            },
            "Byramji": {
                "shipping-address": "Unit nos - 59 to 71 Lower Ground Floor Ginger Square' City Survey No - 1049",
                "retailer": "Rajidi Retail Pvt Ltd",
                "code": "B",
                "storeId": "1392084",
            },
            "Dharampeth": {
                "shipping-address": "Plot No. 151; CTS No. 135 Puja Sabhagrah; Ravi Nagar Square; Ram Nagar",
                "retailer": "Swinsta Ent Private Limited",
                "code": "DH",
                "storeId": "1397624",
            },
            "Mahal": {
                "shipping-address": "Unit no - G-1; Plot no.58; sardar patel timber Dhantoli; NAGPUR- 440027",
                "retailer": "Rajidi Retail Pvt Ltd",
                "code": "MH",
                "storeId": "1393571",
            },
            "Manish Nagar": {
                "shipping-address": "Ground floor 'Jayanti Mansion III; Manish nagar  Nagpur Maharashtra",
                "retailer": "Rajidi Retail Pvt Ltd",
                "code": "MN",
                "storeId": "1392532",
            },
            "Nandanvan": {
                "shipping-address": "Vinayak Tower; Lower Ground Floor; Survey No.212 Gurudev Nagar Main Road; New Nanadanvan",
                "retailer": "Swinsta Ent Private Limited",
                "code": "NA",
                "storeId": "1397035",
            },
            "Sai Mandir": {
                "shipping-address": "Khasra No 18/2; city Survey No.718; House No. 781/B; Situated at Village Ajni",
                "retailer": "Swinsta Ent Private Limited",
                "code": "S",
                "storeId": "1399707",
            },
        },
    },
    "Zepto": {
        "path": {
            "raw": "zepto",
            "cleand": "zepto",
        },
        "input-columns": [
            "No",
            "Article Name",
            "UoM",
            "Invoice Qty.",
            "Rate",
            "Amount",
        ],
        "locations": {
            "Gokulpeth": {"shipping-address": "", "retailer": "Dorgheria"},
            "Mahada": {"shipping-address": "", "retailer": "Dorgheria"},
            "Khamla": {"shipping-address": "", "retailer": "Dorgheria"},
            "Garoba Maidan": {"shipping-address": "", "retailer": "Dorgheria"},
            "Raghuji Nagar": {"shipping-address": "", "retailer": "Dorgheria"},
            "Zingabai Takli": {"shipping-address": "", "retailer": "Dorgheria"},
            "Bhupesh Nagar": {"shipping-address": "", "retailer": "Dorgheria"},
            "Besa": {"shipping-address": "", "retailer": "Dorgheria"},
        },
    },
}

# %% [markdown]
# ##### Imports

# %%
excelBooks: dict[str, List[dict[str, pd.DataFrame]]] = {
    domain: [
        pd.read_excel(path, sheet_name=None)
        for path in glob(
            join(RAW_FOLDER_PATH, domains[domain]["path"]["raw"], "*.xlsx")
        )
    ]
    for domain in domains
}

print(
    f"Found {len(excelBooks)} domains with {sum([len(excelBooks[domain]) for domain in excelBooks])} files."
)

pprint(
    {
        domain: [
            path
            for path in glob(
                join(RAW_FOLDER_PATH, domains[domain]["path"]["raw"], "*.xlsx")
            )
        ]
        for domain in domains
    }
)
# Out:
# Found 2 domains with 10 files.
# {'Swiggy': ['./../../upgrade_mandi/data/raw\\swiggy\\APRIL INVOICES.xlsx',
#             './../../upgrade_mandi/data/raw\\swiggy\\JULY AND AUGUST 2025 '
#             'INVOICES.xlsx',
#             './../../upgrade_mandi/data/raw\\swiggy\\JUNE INVOICES.xlsx',
#             './../../upgrade_mandi/data/raw\\swiggy\\MAY INVOICES.xlsx',
#             './../../upgrade_mandi/data/raw\\swiggy\\OCTOBER 2025 '
#             'INVOICES.xlsx',
#             './../../upgrade_mandi/data/raw\\swiggy\\SEPTEMBER 2025 '
#             'INVOICES.xlsx',
#             './../../upgrade_mandi/data/raw\\swiggy\\Swiggy 09-04-2025 to  '
#             '22-06-2025.xlsx',
#             './../../upgrade_mandi/data/raw\\swiggy\\Swiggy 22-06-2025 to '
#             '31-08-2025.xlsx',
#             './../../upgrade_mandi/data/raw\\swiggy\\Swiggy 28-01-2025 to '
#             '08-04-2025.xlsx'],
#  'Zepto': ['./../../upgrade_mandi/data/raw\\zepto\\Zepto 10-07-2025 - '
#            '20-06-2025.xlsx']}

# %% [markdown]
# ##### Extractor

# %%
class Extract:
    def __checkColumnName(self, col: pd.Series):
        return (
            col.astype(str)
            .apply(
                lambda string: " ".join(
                    list(
                        filter(
                            lambda x: not x.isspace() and x,
                            string.lower().replace("\n", "").split(" "),
                        )
                    )
                )
            )
            .isin(list(map(lambda x: x.lower(), self.columns)))
            .any()
        )

    def __extractTable(self, row: pd.Series) -> bool:
        # print(str(row[self.columns[0]]))
        return str(row[self.columns[0]]).isnumeric()

    def __extractDateLocation(
        self, rawString: str
    ) -> Tuple[datetime, str] | Tuple[bool, bool]:
        datePattern = "^(\d){1,2}[-/](\d){1,2}[-/](\d){4}"
        dateMached = re.match(datePattern, rawString)

        if dateMached:
            dateFormat = "%d-%m-%Y"
            date = datetime.strptime(
                re.sub(r"[-/]", "-", dateMached.group(0)), dateFormat
            ).strftime("%d-%m-%Y")

            area = nameExtracter(
                list(self.locations.keys()),
                rawString,
            ).title()

            return (date, area)
        return (False, False)

    # dict[str, dict[str, str]]
    def __init__(self, columns: List[str], locations: dict, vendorName: str):
        self.columns: List[str] = columns
        self.locations = locations
        self.vendorName = vendorName

        self.locationParsed = {x: [] for x in self.locations}
        self.processedDataFrame: pd.DataFrame = pd.DataFrame(columns=self.columns)

    def extractDataFrame(self, sheetName: str, sheetData: pd.DataFrame):
        sheetNameStriped = sheetName.strip()
        # sheetData.columns = self.columns[:-2]
        date, location = self.__extractDateLocation(sheetNameStriped)
        if date == False:
            return pd.DataFrame()

        sheetData = sheetData[
            sheetData.columns[sheetData.apply(self.__checkColumnName, axis=0)]
        ].copy()

        sheetData.columns = self.columns
        sheetData = sheetData[sheetData.apply(self.__extractTable, axis=1)].copy()

        invoiceVersion = 1
        numbers = re.findall(r"\d+(?:\.\d+)?", sheetNameStriped[11:])
        if numbers:
            invoiceVersion = int(numbers[0])

        sheetData["Date"] = date
        sheetData["Location"] = location
        sheetData["Invoice Version"] = invoiceVersion
        sheetData["Retailer"] = self.locations[location]["retailer"]
        sheetData["Vendor Name"] = self.vendorName
        sheetData["Shipping Address"] = self.locations[location]["shipping-address"]
        sheetData["PO No"] = generatePONo(
            datetime.strptime(date, "%d-%m-%Y"),
            self.locations[location]["storeId"],
            "74227878",
        )

        sheetData["Invoice Version"].astype(int)

        self.locationParsed[location].append(sheetName)

        return sheetData

    def add(self, dataFrame: pd.DataFrame):
        dataFrame = dataFrame.dropna(how="all", axis=1)
        if not dataFrame.empty:
            self.processedDataFrame = pd.concat(
                [self.processedDataFrame, dataFrame], ignore_index=True
            )

    def save(self, fileName, split=-1):
        self.processedDataFrame.to_csv(f"{fileName}.csv", index=False)

# %% [markdown]
# ##### Run

# %%
extractedDomains: dict[str, Extract] = {}

errorSheets: dict[str, List[dict[str, str]]] = {domain: [] for domain in domains}

for domain in domains:
    if domain == "Zepto":
        continue

    extract = Extract(
        domains[domain]["input-columns"],
        domains[domain]["locations"],
        "Upgrade Mandi",
    )
    for excelBook in excelBooks[domain]:
        count = 0
        for sheetName, sheetData in excelBook.items():
            if sheetData.empty:
                errorSheets[domain].append({sheetName: "Empty sheet"})
                continue

            df = extract.extractDataFrame(sheetName, sheetData)
            try:
                if not df.empty:
                    extract.add(df)
                else:
                    errorSheets[domain].append({sheetName: "Empty DataFrame"})
            except Exception as e:
                errorSheets[domain].append({sheetName: str(e)})
                break
            count += 1
            pretty(domain, count, len(excelBook), 30)
        print()
    print(f"Processed {domain} data.\n")

    extractedDomains[domain] = extract

print("The following sheets are not parsed: ")
pprint(errorSheets)
# Out:
# Swiggy [==============================] 100%
# Swiggy [==============================] 100%
# Swiggy [==============================] 100%
# Swiggy [==============================] 100%
# Swiggy [=============================] 99%
# Swiggy [==============================] 100%
# Swiggy [=============================] 99%
# Swiggy [=============================] 98%
# Swiggy [==============================] 100%
# Processed Swiggy data.
#
# The following sheets are not parsed:
# {'Swiggy': [{'Copy of 03-04-2025 DHARAMPETH': 'Empty DataFrame'},
#             {'Copy of 04-04-2025 MAHAL': 'Empty DataFrame'},
#             {'Copy of 04-04-2025 DHARAMPETH': 'Empty DataFrame'},
#             {'Copy of 04-04-2025 SAI MANDIR': 'Empty DataFrame'},
#             {'Copy of 04-04-2025 NANDANWAN': 'Empty DataFrame'},
#             {'Copy of 04-04-2025 BYRAMJI': 'Empty DataFrame'},
#             {'Copy of 04-04-2025 MANISH NAGAR': 'Empty DataFrame'},
#             {'Copy of 04-04-2025 AYODHYA NAGA': 'Empty DataFrame'},
#             {'Copy of 06-04-2025 SAI MANDIR': 'Empty DataFrame'},
#             {'Copy of 06-04-2025 AYODHYA NAGA': 'Empty DataFrame'},
#             {'Copy of 06-04-2025 MANISH NAGAR': 'Empty DataFrame'},
#             {'Copy of 06-04-2025 BYRAMJI': 'Empty DataFrame'},
#             {'Copy of 06-04-2025 NANDANWAN': 'Empty DataFrame'},
#             {'Copy of 06-04-2025 MAHAL': 'Empty DataFrame'},
#             {'Copy of 06-04-2025 DHARAMPETH': 'Empty DataFrame'},
#             {'Copy of 07-04-2025 MANISH NAGAR': 'Empty DataFrame'},
#             {'Copy of 07-04-2025 DHARAMPETH': 'Empty DataFrame'},
#             {'Copy of 07-04-2025 MAHAL': 'Empty DataFrame'},
#             {'Copy of 07-04-2025 NANDANWAN': 'Empty DataFrame'},
#             {'Copy of 07-04-2025 BYRAMJI': 'Empty DataFrame'},
#             {'Copy of 07-04-2025 SAI MANDIR': 'Empty DataFrame'},
#             {'Copy of 07-04-2025 AYODHYA NAGA': 'Empty DataFrame'},
#             {'Copy of 08-04-2025 BYRAMJI': 'Empty DataFrame'},
#             {'Copy of 08-04-2025 NANDANWAN': 'Empty DataFrame'},
#             {'Copy of 08-04-2025 BYRAMJI ': 'Empty DataFrame'},
#             {'Copy of 08-04-2025 DHARAMPETH': 'Empty DataFrame'},
#             {'Copy of 08-04-2025 MAHAL': 'Empty DataFrame'},
#             {'Copy of 08-04-2025 AYODHYA NAGA': 'Empty DataFrame'},
#             {'Copy of 08-04-2025 SAI MANDIR': 'Empty DataFrame'},
#             {'Copy of 08-04-2025 MANISH NAGAR': 'Empty DataFrame'},
#             {'Sheet245': 'Empty DataFrame'},
#             {'Sheet246': 'Empty DataFrame'},
#             {'Sheet247': 'Empty DataFrame'},
#             {'20-10-2025 MAHAL': 'Empty sheet'},
#             {'20-10-2025 NANDANVAN': 'Empty sheet'},
#             {'Sheet190': 'Empty DataFrame'},
#             {'Sheet191': 'Empty DataFrame'},
#             {'Sheet192': 'Empty DataFrame'},
#             {'Sheet193': 'Empty DataFrame'},
#             {'Sheet194': 'Empty DataFrame'},
#             {'Sheet195': 'Empty DataFrame'},
#             {'Sheet196': 'Empty DataFrame'},
#             {'Sheet197': 'Empty DataFrame'},
#             {'Sheet198': 'Empty DataFrame'},
#             {'Sheet199': 'Empty DataFrame'},
#             {'Sheet200': 'Empty DataFrame'},
#             {'Sheet201': 'Empty DataFrame'},
#             {'Sheet202': 'Empty DataFrame'},
#             {'Sheet203': 'Empty DataFrame'},
#             {'Sheet204': 'Empty DataFrame'},
#             {'Sheet205': 'Empty DataFrame'},
#             {'Sheet206': 'Empty DataFrame'},
#             {'Sheet207': 'Empty DataFrame'},
#             {'Sheet208': 'Empty DataFrame'},
#             {'Sheet209': 'Empty DataFrame'},
#             {'Sheet210': 'Empty DataFrame'},
#             {'Sheet211': 'Empty DataFrame'},
#             {'Sheet212': 'Empty DataFrame'},
#             {'Sheet213': 'Empty DataFrame'},
#             {'Sheet214': 'Empty DataFrame'},
#             {'Sheet215': 'Empty DataFrame'},
#             {'Sheet216': 'Empty DataFrame'},
#             {'Sheet217': 'Empty DataFrame'},
#             {'Sheet218': 'Empty DataFrame'},
#             {'Sheet219': 'Empty DataFrame'},
#             {'Sheet220': 'Empty DataFrame'},
#             {'Sheet221': 'Empty DataFrame'},
#             {'Sheet222': 'Empty DataFrame'},
#             {'Sheet223': 'Empty DataFrame'},
#             {'Sheet224': 'Empty DataFrame'},
#             {'Sheet225': 'Empty DataFrame'},
#             {'Sheet226': 'Empty DataFrame'},
#             {'Sheet227': 'Empty DataFrame'},
#             {'Sheet228': 'Empty DataFrame'},
#             {'Sheet229': 'Empty DataFrame'},
#             {'Sheet230': 'Empty DataFrame'},
#             {'Sheet231': 'Empty DataFrame'},
#             {'Sheet232': 'Empty DataFrame'},
#             {'Sheet233': 'Empty DataFrame'},
#             {'Sheet234': 'Empty DataFrame'},
#             {'Sheet235': 'Empty DataFrame'},
#             {'Sheet236': 'Empty DataFrame'},
#             {'Sheet237': 'Empty DataFrame'},
#             {'Sheet238': 'Empty DataFrame'},
#             {'Sheet239': 'Empty DataFrame'},
#             {'Sheet240': 'Empty DataFrame'},
#             {'Sheet241': 'Empty DataFrame'},
#             {'Sheet242': 'Empty DataFrame'},
#             {'Sheet158': 'Empty DataFrame'},
#             {'Sheet228': 'Empty DataFrame'},
#             {'12-09-202 BYRAMJI 2': 'Empty DataFrame'},
#             {'12-09-202 MANISH NAGAR 2': 'Empty DataFrame'},
#             {'12-09-202 MAHAL 2': 'Empty DataFrame'},
#             {'12-09-202 NANDANVAN 2': 'Empty DataFrame'},
#             {'Sheet3': 'Empty sheet'},
#             {'Sheet467': 'Empty sheet'},
#             {'Sheet474': 'Empty sheet'},
#             {'Sheet475': 'Empty sheet'},
#             {'Sheet476': 'Empty sheet'},
#             {'Sheet477': 'Empty sheet'},
#             {'Sheet478': 'Empty sheet'},
#             {'Sheet479': 'Empty sheet'}],
#  'Zepto': []}

# %%
extractedDomains["Swiggy"].processedDataFrame.drop_duplicates().to_csv(
    join(CLEANED_FOLDER_PATH, "swiggy", "Swiggy Invoice (Data).csv")
)

# %%
extractedDomains["Swiggy"].processedDataFrame["Total Amount"].sum()
# Out:
# 17729320.0

# %%
grnPr = pd.read_csv("./GRN PR (Swiggy).csv")

# %%
month_to_extract = "09-2025"
month = extractedDomains["Swiggy"].processedDataFrame[
    extractedDomains["Swiggy"]
    .processedDataFrame["Date"]
    .apply(lambda x: str(x)[3:] == month_to_extract)
]

# %%
dct = {
    location.name: location.code for location in domainConfigClass["Swiggy"].locations
}

month["Invoice Number"] = (
    month["Date"]
    .apply(lambda x: datetime.strptime(str(x), "%d-%m-%Y").strftime("%d-%m-%Y"))
    .str.replace("-", "")
    + "U"
    + month["Location"].apply(lambda x: dct[x])
    + month["Invoice Version"].astype(int).astype(str)
)
# Out:
# C:\Users\cw\AppData\Local\Temp\ipykernel_16328\2054747611.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month["Invoice Number"] = (

# %%
month["GRN Quantity"] = 0
month["GRN Amount"] = 0
month["PR Quantity"] = 0
month["PR Amount"] = 0
# Out:
# C:\Users\cw\AppData\Local\Temp\ipykernel_16328\1689003593.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month["GRN Quantity"] = 0
# C:\Users\cw\AppData\Local\Temp\ipykernel_16328\1689003593.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month["GRN Amount"] = 0
# C:\Users\cw\AppData\Local\Temp\ipykernel_16328\1689003593.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month["PR Quantity"] = 0
# C:\Users\cw\AppData\Local\Temp\ipykernel_16328\1689003593.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month["PR Amount"] = 0

# %%
merged = month.merge(
    right=grnPr,
    how="left",
    left_on="Invoice Number",
    right_on="Invoice Number",
)

# %%
merged_remove_x = merged[
    merged.columns.difference(
        ["GRN Quantity_x", "GRN Amount_x", "PR Quantity_x", "PR Amount_x"]
    )
]

# %%
grp_keys = [
    "Date",
    "Invoice Number",
    "Location",
    "Retailer",
    "GRN Amount_y",
    "PR Amount_y",
]

grp = merged_remove_x.groupby(grp_keys, dropna=False)["Total Amount"].sum()

# %%
to_save = pd.DataFrame(grp.index.to_list(), columns=grp_keys)

# %%
to_save["Total Amount"] = grp.values

# %%
to_save.to_csv(
    f"./../data/cleaned/swiggy/Swiggy Collected - GRN PR {month_to_extract}.csv",
    index=False,
)

# %%
for domain in extractedDomains:
    extractedDomains[domain].save(join(CLEANED_FOLDER_PATH, domain.lower(), domain))

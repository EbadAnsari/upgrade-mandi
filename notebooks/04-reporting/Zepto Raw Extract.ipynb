# %%
import pandas as pd
import numpy as np

from utils.config import domainConfigClass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       1 import pandas as pd
#       2 import numpy as np
# ----> 4 from utils.config import domainConfigClass
#
# File d:\Programming\Project\Upgrade Mandi\notebooks\04-reporting\utils\config.py:11
#       8 from typing import Union
#      10 from dotenv import load_dotenv
# ---> 11 from type.domain_types import (
#      12     ColumnConfig,
#      13     DatabaseConfig,
#      14     InvoicePdfConfig,
#      15     Location,
#      16     Mobile,
#      17     RawSheetConfig,
#      18     Swiggy,
#      19     VendorConfig,
#      20     Zepto,
#      21 )
#      23 load_dotenv()
#      25 # Project root directory
#
# File d:\Programming\Project\Upgrade Mandi\notebooks\04-reporting\type\domain_types.py:127
#     123     def invoiceNo(self, date: datetime, vendorCode: str) -> str:
# ...

# %%
df = pd.read_excel("./../../upgrade_mandi/raw-sheets-dump/zepto raw.xlsx", header=1)

# %%
df.columns = [column.strip() for column in df.columns]

# %%
df["UoM"] = df["UoM"].apply(lambda uom: "#N/A" if str(uom) == "nan" else uom)

# %%
dropColumns = df.drop(columns=["Product Code"], axis=0)

# %%
dropColumns
# Out:
#            Product Name       UoM     Vendor Name  NAG-Besa  \
# 0          Tomato Local  500 GRAM  Upgrade Mandi         39
# 1    Ivy Gourd (Tindli)      #N/A  Upgrade Mandi          3
# 2                 Lemon  250 GRAM  Upgrade Mandi          5
# 3     Cucumber (Kheera)   2 PIECE  Upgrade Mandi          5
# 4              Beetroot  500 GRAM  Upgrade Mandi          3
# 5               Cabbage   1 PIECE  Upgrade Mandi         13
# 6            Drumsticks   2 PIECE  Upgrade Mandi          0
# 7   Forest Bitter Gourd  250 GRAM  Upgrade Mandi          0
# 8        Brinjal Bharta   1 PIECE  Upgrade Mandi          2
# 9           Carrot Ooty         4  Upgrade Mandi          2
# 10          Baby Potato  250 GRAM  Upgrade Mandi          0
# 11        Brinjal Small  250 GRAM  Upgrade Mandi          6
# 12       Capsicum Small  250 GRAM  Upgrade Mandi          0
# 13          Cauliflower   1 PIECE  Upgrade Mandi         10
# 14         Bottle Gourd   1 PIECE  Upgrade Mandi          2
# ...

# %%
finalDf = {
    for location in domainConfigClass["Zepto"]
}
# Out:
#   Cell In[9], line 2
#     for location in domain
#     ^
# SyntaxError: invalid syntax
